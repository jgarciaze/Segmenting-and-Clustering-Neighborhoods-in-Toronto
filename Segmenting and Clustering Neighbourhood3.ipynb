# %% [markdown]
# <h1 align=center><font size = 10><font color='blue'>DS Course CAPSTONE Segmenting and Clustering Neigborhood - TORONTO</font></h1>

# %% [markdown]
# # Part III:  Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ### let install and import all the necessary package

# %%
# install geopy package
# !pip install geopy

# %%
#import all the needed library
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ### now, we need to read the last dataset, and clean

# %%
t_df= pd.read_csv('t_dataframe.csv')
t_df.drop(['Unnamed: 0'], axis=1, inplace= True)
t_df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ### according to the instruction, we need to list "toronto" words in Borough

# %%
newdf=t_df[t_df['Borough'].str.contains('Toronto')]
df=newdf.reset_index(drop=True)
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %% [markdown]
# ### lets see the dimension of the new dataframe and the values in Borough column

# %%
df.shape
# Out:
# (39, 5)

# %%
# see values in Borough column
df['Borough'].value_counts()
# Out:
# Downtown Toronto    19
# Central Toronto      9
# West Toronto         6
# East Toronto         5
# Name: Borough, dtype: int64

# %% [markdown]
# # Now we gonna take "Borough" as a label and put in the dataframe, (borough has many values variation than the other colunms so that's why its better label convert option)

# %%
df['Label']=df['Borough'].replace(to_replace=['Downtown Toronto','Central Toronto','West Toronto','East Toronto'],value=[1,2,3,4],inplace=False)
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude  Label
# 0  43.654260 -79.360636      1
# 1  43.662301 -79.389494      1
# 2  43.657162 -79.378937      1
# 3  43.651494 -79.375418      1
# 4  43.676357 -79.293031      4

# %% [markdown]
# ### now, let's view the coordinate Latitude,Longitud for Toronto adress

# %%
address = 'Toronto'
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(f'The geograpical coordinate of Toronto are {latitude}, {longitude}.')
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ### is time to use Folium to clusterize and Organize our Data into a Map

# %%
kclusters=len(df.Label.unique())
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]


markers_colors = []
for lat, lon, cluster in zip(df['Latitude'], df['Longitude'], df['Label']):
    label = folium.Popup(str(df['Borough']) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_toronto)

# %% [markdown]
# ### Result bellow of all the work!

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### end of Part III
